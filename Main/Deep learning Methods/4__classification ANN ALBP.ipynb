# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from keras import regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import classification_report

# %%
# Step 1: Load the data
train_df = pd.read_csv('data/train_test/ALBP/train_ALBP.csv')
test_df = pd.read_csv('data/train_test/ALBP/test_ALBP.csv')

# Separate features and labels
X_train = train_df.drop(columns=['label'])
y_train = train_df['label']

X_test = test_df.drop(columns=['label'])
y_test = test_df['label']

# Step 2: Preprocess the data
# Normalize pixel values
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Convert labels to one-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y_train = encoder.fit_transform(y_train.values.reshape(-1, 1))
y_test = encoder.transform(y_test.values.reshape(-1, 1))

print('Train: ' + str(len(X_train)) + ' Test: ' + str(len(X_test)))
# Out:
# Train: 2500 Test: 300

# %%
# # Step 3: Build the ANN model
# model = keras.Sequential([
#     keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
#     keras.layers.Dropout(0.5),
#     keras.layers.Dense(256, activation='relu'),
#     keras.layers.Dropout(0.5),
#     keras.layers.Dense(100, activation='softmax')  # 100 classes
# ])

# Step 3: Build the ANN model with optimizations
model = keras.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    keras.layers.Dense(100, activation='softmax')  # 100 classes
])

# Step 4: Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Step 5: Train the model
history = model.fit(X_train, y_train, validation_split=0.3, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9506 - loss: 1.9606 - val_accuracy: 0.3293 - val_loss: 21.0084
# Epoch 2/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9387 - loss: 1.8808 - val_accuracy: 0.3333 - val_loss: 21.8396
# Epoch 3/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9595 - loss: 1.7219 - val_accuracy: 0.3307 - val_loss: 23.5342
# Epoch 4/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9532 - loss: 1.8640 - val_accuracy: 0.3293 - val_loss: 24.1182
# Epoch 5/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9745 - loss: 1.5555 - val_accuracy: 0.3293 - val_loss: 24.2057
# Epoch 6/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9632 - loss: 1.7688 - val_accuracy: 0.3307 - val_loss: 26.0111
# Epoch 7/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9465 - loss: 1.9822 - val_accuracy: 0.3267 - val_loss: 23.5073
# Epoch 8/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9749 - loss: 1.4098 - val_accuracy: 0.3173 - val_loss: 25.4231
# Epoch 9/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9676 - loss: 1.7405 - val_accuracy: 0.3173 - val_loss: 27.6416
# Epoch 10/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9626 - loss: 1.6852 - val_accuracy: 0.3147 - val_loss: 27.1217
# Epoch 11/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.9623 - loss: 1.7411 - val_accuracy: 0.3107 - val_loss: 27.9625
# Epoch 12/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9646 - loss: 1.8785 - val_accuracy: 0.3107 - val_loss: 27.4066
# Epoch 13/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9622 - loss: 1.9145 - val_accuracy: 0.3107 - val_loss: 30.6589
# Epoch 14/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 102ms/step - accuracy: 0.9726 - loss: 1.7869 - val_accuracy: 0.2920 - val_loss: 30.0459
# Epoch 15/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 101ms/step - accuracy: 0.9690 - loss: 1.7509 - val_accuracy: 0.2920 - val_loss: 30.7490
# Epoch 16/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9648 - loss: 1.9681 - val_accuracy: 0.2800 - val_loss: 29.3689
# Epoch 17/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9657 - loss: 1.6361 - val_accuracy: 0.2933 - val_loss: 28.0315
# Epoch 18/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9657 - loss: 1.8802 - val_accuracy: 0.2733 - val_loss: 33.8402
# Epoch 19/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9688 - loss: 1.8964 - val_accuracy: 0.2773 - val_loss: 34.8010
# Epoch 20/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9705 - loss: 1.7690 - val_accuracy: 0.2613 - val_loss: 33.6867
# Epoch 21/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9661 - loss: 1.9359 - val_accuracy: 0.2640 - val_loss: 32.5697
# Epoch 22/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9647 - loss: 1.7818 - val_accuracy: 0.2880 - val_loss: 30.2132
# Epoch 23/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9772 - loss: 1.7739 - val_accuracy: 0.2653 - val_loss: 32.2131
# Epoch 24/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9716 - loss: 1.8227 - val_accuracy: 0.2667 - val_loss: 32.7830
# Epoch 25/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9741 - loss: 1.9584 - val_accuracy: 0.2667 - val_loss: 31.3646
# Epoch 26/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9761 - loss: 1.7396 - val_accuracy: 0.2453 - val_loss: 34.2226
# Epoch 27/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9659 - loss: 2.1149 - val_accuracy: 0.2493 - val_loss: 36.6045
# Epoch 28/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9744 - loss: 1.7068 - val_accuracy: 0.2693 - val_loss: 36.7523
# Epoch 29/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9755 - loss: 1.8323 - val_accuracy: 0.2400 - val_loss: 36.6295
# Epoch 30/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9647 - loss: 2.1889 - val_accuracy: 0.1987 - val_loss: 34.2912
# Epoch 31/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9705 - loss: 2.1721 - val_accuracy: 0.2187 - val_loss: 34.9812
# Epoch 32/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9712 - loss: 2.0738 - val_accuracy: 0.2133 - val_loss: 31.9564
# Epoch 33/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9746 - loss: 1.9685 - val_accuracy: 0.1573 - val_loss: 36.2361
# Epoch 34/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9716 - loss: 2.2296 - val_accuracy: 0.1613 - val_loss: 31.6705
# Epoch 35/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9753 - loss: 1.7561 - val_accuracy: 0.1840 - val_loss: 31.5115
# Epoch 36/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9765 - loss: 1.8182 - val_accuracy: 0.1947 - val_loss: 34.9037
# Epoch 37/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9695 - loss: 2.4031 - val_accuracy: 0.1880 - val_loss: 36.1974
# Epoch 38/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9665 - loss: 2.3897 - val_accuracy: 0.2000 - val_loss: 32.7059
# Epoch 39/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9735 - loss: 1.8267 - val_accuracy: 0.2040 - val_loss: 34.3205
# Epoch 40/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9531 - loss: 2.5063 - val_accuracy: 0.1773 - val_loss: 37.1316
# Epoch 41/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9753 - loss: 2.0963 - val_accuracy: 0.1320 - val_loss: 42.6659
# Epoch 42/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9797 - loss: 1.9467 - val_accuracy: 0.1360 - val_loss: 41.9603
# Epoch 43/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9800 - loss: 1.8937 - val_accuracy: 0.1387 - val_loss: 40.9425
# Epoch 44/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9741 - loss: 2.2437 - val_accuracy: 0.1333 - val_loss: 46.5560
# Epoch 45/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9657 - loss: 2.2283 - val_accuracy: 0.1120 - val_loss: 46.5693
# Epoch 46/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9746 - loss: 2.5880 - val_accuracy: 0.1400 - val_loss: 50.0808
# Epoch 47/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9711 - loss: 2.2712 - val_accuracy: 0.1107 - val_loss: 47.5933
# Epoch 48/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.9721 - loss: 2.2896 - val_accuracy: 0.1387 - val_loss: 51.4758
# Epoch 49/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.9727 - loss: 2.0612 - val_accuracy: 0.1360 - val_loss: 50.6137
# Epoch 50/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.9822 - loss: 1.9949 - val_accuracy: 0.1160 - val_loss: 48.4525

# %%
# Step 6: Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy:.2f}")

# Step 7: Generate classification report
y_pred = model.predict(X_test)
y_pred_labels = encoder.inverse_transform(y_pred)
y_test_labels = encoder.inverse_transform(y_test)
print(classification_report(y_test_labels, y_pred_labels))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8231 - loss: 7.1574
# Test accuracy: 0.65
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#               precision    recall  f1-score   support
#
#            1       0.38      1.00      0.55         3
#            2       1.00      1.00      1.00         3
#            3       0.33      1.00      0.50         3
#            4       0.75      1.00      0.86         3
#            5       0.43      1.00      0.60         3
#            6       1.00      1.00      1.00         3
#            7       0.60      1.00      0.75         3
#            8       0.00      0.00      0.00         3
#            9       0.00      0.00      0.00         3
#           10       0.50      1.00      0.67         3
#           11       0.50      1.00      0.67         3
#           12       0.75      1.00      0.86         3
#           13       0.67      0.67      0.67         3
#           14       0.60      1.00      0.75         3
#           15       1.00      1.00      1.00         3
#           16       0.33      0.67      0.44         3
#           17       1.00      0.67      0.80         3
#           18       1.00      1.00      1.00         3
#           19       1.00      1.00      1.00         3
#           20       0.38      1.00      0.55         3
#           21       1.00      0.67      0.80         3
#           22       0.22      0.67      0.33         3
#           23       0.75      1.00      0.86         3
#           24       1.00      1.00      1.00         3
#           25       1.00      1.00      1.00         3
#           26       1.00      1.00      1.00         3
#           27       1.00      1.00      1.00         3
#           28       0.50      1.00      0.67         3
#           29       1.00      1.00      1.00         3
#           30       1.00      1.00      1.00         3
#           31       0.75      1.00      0.86         3
#           32       1.00      1.00      1.00         3
#           33       1.00      1.00      1.00         3
#           34       1.00      0.67      0.80         3
#           35       1.00      1.00      1.00         3
#           36       1.00      0.33      0.50         3
#           37       1.00      1.00      1.00         3
#           38       1.00      1.00      1.00         3
#           39       1.00      1.00      1.00         3
#           40       1.00      0.33      0.50         3
#           41       0.43      1.00      0.60         3
#           42       1.00      0.33      0.50         3
#           43       0.38      1.00      0.55         3
#           44       0.75      1.00      0.86         3
#           45       0.75      1.00      0.86         3
#           46       1.00      1.00      1.00         3
#           47       1.00      0.67      0.80         3
#           48       0.38      1.00      0.55         3
#           49       0.60      1.00      0.75         3
#           50       0.25      0.33      0.29         3
#           51       0.50      1.00      0.67         3
#           52       0.60      1.00      0.75         3
#           53       0.60      1.00      0.75         3
#           54       0.33      0.67      0.44         3
#           55       1.00      1.00      1.00         3
#           56       1.00      1.00      1.00         3
#           57       0.60      1.00      0.75         3
#           58       1.00      1.00      1.00         3
#           59       0.50      0.33      0.40         3
#           60       1.00      1.00      1.00         3
#           61       1.00      1.00      1.00         3
#           62       0.75      1.00      0.86         3
#           63       1.00      1.00      1.00         3
#           64       0.40      0.67      0.50         3
#           65       0.50      1.00      0.67         3
#           66       0.75      1.00      0.86         3
#           67       1.00      1.00      1.00         3
#           68       1.00      0.67      0.80         3
#           69       0.50      1.00      0.67         3
#           70       0.50      1.00      0.67         3
#           71       0.43      1.00      0.60         3
#           72       1.00      0.33      0.50         3
#           73       1.00      0.67      0.80         3
#           74       0.00      0.00      0.00         3
#           75       1.00      0.67      0.80         3
#           76       0.00      0.00      0.00         3
#           77       0.00      0.00      0.00         3
#           78       0.00      0.00      0.00         3
#           79       0.00      0.00      0.00         3
#           80       0.00      0.00      0.00         3
#           81       0.00      0.00      0.00         3
#           82       0.00      0.00      0.00         3
#           83       0.00      0.00      0.00         3
#           84       0.00      0.00      0.00         3
#           85       0.00      0.00      0.00         3
#           86       0.00      0.00      0.00         3
#           87       0.00      0.00      0.00         3
#           88       0.00      0.00      0.00         3
#           89       0.00      0.00      0.00         3
#           90       0.00      0.00      0.00         3
#           91       0.00      0.00      0.00         3
#           92       0.00      0.00      0.00         3
#           93       0.00      0.00      0.00         3
#           94       0.00      0.00      0.00         3
#           95       0.00      0.00      0.00         3
#           96       0.00      0.00      0.00         3
#           97       0.00      0.00      0.00         3
#           98       0.00      0.00      0.00         3
#           99       0.00      0.00      0.00         3
#          100       0.50      1.00      0.67         3
#
#     accuracy                           0.65       300
#    macro avg       0.55      0.65      0.57       300
# weighted avg       0.55      0.65      0.57       300
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import matplotlib.pyplot as plt

# Plot the training loss over epochs
plt.plot(history.history['loss'], label='Training Loss')  # Training loss over epochs
plt.plot(history.history['val_loss'], label='Validation Loss')  # Training loss over epochs
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Loss')  # Y-axis label
plt.title('Training Loss Over Epochs')  # Plot title
plt.legend()  # Display the legend
plt.show()  # Display the plot

# Plot the training accuracy over epochs
plt.plot(history.history['accuracy'], label='Training Accuracy')  # Training accuracy over epochs
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Training accuracy over epochs
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label
plt.title('Training Accuracy Over Epochs')  # Plot title
plt.legend()  # Display the legend
plt.show()  # Display the plot
