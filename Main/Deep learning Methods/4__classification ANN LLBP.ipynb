# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from keras import regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import classification_report

# %%
# Step 1: Load the data
train_df = pd.read_csv('data/train_test/LLBP/train_LLBP.csv')
test_df = pd.read_csv('data/train_test/LLBP/test_LLBP.csv')

# Separate features and labels
X_train = train_df.drop(columns=['label'])
y_train = train_df['label']

X_test = test_df.drop(columns=['label'])
y_test = test_df['label']

# Step 2: Preprocess the data
# Normalize pixel values
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Convert labels to one-hot encoding
encoder = OneHotEncoder(sparse=False)
y_train = encoder.fit_transform(y_train.values.reshape(-1, 1))
y_test = encoder.transform(y_test.values.reshape(-1, 1))

print('Train: ' + str(len(X_train)) + ' Test: ' + str(len(X_test)))
# Out:
# Train: 1200 Test: 200
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Step 3: Build the ANN model
# model = keras.Sequential([
#     keras.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
#     # keras.layers.Dropout(0.5),
#     keras.layers.Dense(256, activation='relu'),
#     keras.layers.Dropout(0.2),
#     keras.layers.Dense(100, activation='softmax')  # 100 classes
# ])

# Step 3: Build the ANN model with optimizations
model = keras.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    keras.layers.Dense(100, activation='softmax')  # 100 classes
])

# Step 4: Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Step 5: Train the model
history = model.fit(X_train, y_train, validation_split=0.1, epochs=75, batch_size=32)
# Out:
# Epoch 1/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.7999 - loss: 5.8456 - val_accuracy: 0.0000e+00 - val_loss: 23.8797
# Epoch 2/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.7070 - loss: 2.3868 - val_accuracy: 0.0000e+00 - val_loss: 25.4423
# Epoch 3/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8222 - loss: 1.5157 - val_accuracy: 0.0000e+00 - val_loss: 29.7304
# Epoch 4/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8363 - loss: 1.4737 - val_accuracy: 0.0000e+00 - val_loss: 29.2778
# Epoch 5/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8862 - loss: 1.3617 - val_accuracy: 0.0000e+00 - val_loss: 33.0724
# Epoch 6/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8804 - loss: 1.4600 - val_accuracy: 0.0000e+00 - val_loss: 27.6920
# Epoch 7/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8775 - loss: 1.1358 - val_accuracy: 0.0000e+00 - val_loss: 28.9983
# Epoch 8/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9068 - loss: 1.0127 - val_accuracy: 0.0000e+00 - val_loss: 33.0268
# Epoch 9/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9136 - loss: 1.0209 - val_accuracy: 0.0000e+00 - val_loss: 35.3689
# Epoch 10/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9172 - loss: 1.0075 - val_accuracy: 0.0000e+00 - val_loss: 38.3313
# Epoch 11/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9145 - loss: 0.9949 - val_accuracy: 0.0000e+00 - val_loss: 38.1938
# Epoch 12/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9239 - loss: 0.9649 - val_accuracy: 0.0000e+00 - val_loss: 40.4037
# Epoch 13/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9496 - loss: 0.8171 - val_accuracy: 0.0000e+00 - val_loss: 36.9256
# Epoch 14/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9431 - loss: 0.9114 - val_accuracy: 0.0000e+00 - val_loss: 40.0823
# Epoch 15/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9273 - loss: 0.9467 - val_accuracy: 0.0000e+00 - val_loss: 40.5159
# Epoch 16/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9367 - loss: 0.9291 - val_accuracy: 0.0000e+00 - val_loss: 39.8790
# Epoch 17/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9336 - loss: 0.9107 - val_accuracy: 0.0000e+00 - val_loss: 41.9665
# Epoch 18/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9562 - loss: 0.8571 - val_accuracy: 0.0000e+00 - val_loss: 41.0827
# Epoch 19/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9426 - loss: 0.8868 - val_accuracy: 0.0000e+00 - val_loss: 43.1081
# Epoch 20/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9496 - loss: 0.8535 - val_accuracy: 0.0000e+00 - val_loss: 45.7136
# Epoch 21/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9393 - loss: 0.9136 - val_accuracy: 0.0000e+00 - val_loss: 47.1558
# Epoch 22/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9359 - loss: 0.9415 - val_accuracy: 0.0000e+00 - val_loss: 42.1187
# Epoch 23/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9453 - loss: 0.9011 - val_accuracy: 0.0000e+00 - val_loss: 47.0587
# Epoch 24/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9276 - loss: 1.0672 - val_accuracy: 0.0000e+00 - val_loss: 45.1649
# Epoch 25/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9390 - loss: 0.8936 - val_accuracy: 0.0000e+00 - val_loss: 53.3796
# Epoch 26/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9288 - loss: 0.9715 - val_accuracy: 0.0000e+00 - val_loss: 53.7065
# Epoch 27/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9468 - loss: 0.9274 - val_accuracy: 0.0000e+00 - val_loss: 61.5524
# Epoch 28/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9311 - loss: 1.0394 - val_accuracy: 0.0000e+00 - val_loss: 57.6906
# Epoch 29/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9442 - loss: 0.8732 - val_accuracy: 0.0000e+00 - val_loss: 50.0156
# Epoch 30/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9294 - loss: 1.0098 - val_accuracy: 0.0000e+00 - val_loss: 50.4453
# Epoch 31/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9326 - loss: 1.0505 - val_accuracy: 0.0000e+00 - val_loss: 45.4766
# Epoch 32/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9222 - loss: 1.0823 - val_accuracy: 0.0000e+00 - val_loss: 48.8003
# Epoch 33/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9612 - loss: 0.8007 - val_accuracy: 0.0000e+00 - val_loss: 52.7424
# Epoch 34/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9480 - loss: 0.8539 - val_accuracy: 0.0000e+00 - val_loss: 54.0691
# Epoch 35/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9318 - loss: 1.0705 - val_accuracy: 0.0000e+00 - val_loss: 55.2677
# Epoch 36/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9416 - loss: 0.9944 - val_accuracy: 0.0000e+00 - val_loss: 55.8549
# Epoch 37/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9377 - loss: 1.1075 - val_accuracy: 0.0000e+00 - val_loss: 61.2918
# Epoch 38/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9301 - loss: 1.1862 - val_accuracy: 0.0000e+00 - val_loss: 54.8750
# Epoch 39/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9069 - loss: 1.4773 - val_accuracy: 0.0000e+00 - val_loss: 50.7848
# Epoch 40/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9460 - loss: 1.0303 - val_accuracy: 0.0000e+00 - val_loss: 50.2316
# Epoch 41/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9360 - loss: 1.0043 - val_accuracy: 0.0000e+00 - val_loss: 53.3806
# Epoch 42/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9464 - loss: 0.9465 - val_accuracy: 0.0000e+00 - val_loss: 54.1946
# Epoch 43/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9552 - loss: 0.9264 - val_accuracy: 0.0000e+00 - val_loss: 60.2312
# Epoch 44/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9368 - loss: 1.0280 - val_accuracy: 0.0000e+00 - val_loss: 61.5926
# Epoch 45/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9220 - loss: 1.1431 - val_accuracy: 0.0000e+00 - val_loss: 65.1954
# Epoch 46/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9348 - loss: 0.9766 - val_accuracy: 0.0000e+00 - val_loss: 66.2837
# Epoch 47/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9316 - loss: 1.2646 - val_accuracy: 0.0000e+00 - val_loss: 59.1609
# Epoch 48/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9180 - loss: 1.2619 - val_accuracy: 0.0000e+00 - val_loss: 53.2538
# Epoch 49/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9209 - loss: 1.1436 - val_accuracy: 0.0000e+00 - val_loss: 52.9637
# Epoch 50/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9385 - loss: 1.0180 - val_accuracy: 0.0000e+00 - val_loss: 59.2643
# Epoch 51/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9346 - loss: 1.0911 - val_accuracy: 0.0000e+00 - val_loss: 58.3093
# Epoch 52/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.9350 - loss: 1.0607 - val_accuracy: 0.0000e+00 - val_loss: 61.4158
# Epoch 53/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9543 - loss: 0.9071 - val_accuracy: 0.0000e+00 - val_loss: 63.2794
# Epoch 54/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9364 - loss: 1.1135 - val_accuracy: 0.0000e+00 - val_loss: 60.3625
# Epoch 55/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9615 - loss: 0.8273 - val_accuracy: 0.0000e+00 - val_loss: 65.2640
# Epoch 56/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9655 - loss: 0.9200 - val_accuracy: 0.0000e+00 - val_loss: 62.7493
# Epoch 57/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9526 - loss: 1.0744 - val_accuracy: 0.0000e+00 - val_loss: 71.2540
# Epoch 58/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9460 - loss: 1.1000 - val_accuracy: 0.0000e+00 - val_loss: 59.3630
# Epoch 59/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9411 - loss: 1.0895 - val_accuracy: 0.0000e+00 - val_loss: 65.4502
# Epoch 60/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9504 - loss: 1.0656 - val_accuracy: 0.0000e+00 - val_loss: 68.0354
# Epoch 61/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9154 - loss: 1.4841 - val_accuracy: 0.0000e+00 - val_loss: 67.1415
# Epoch 62/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9256 - loss: 1.2148 - val_accuracy: 0.0000e+00 - val_loss: 72.3986
# Epoch 63/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9442 - loss: 1.0247 - val_accuracy: 0.0000e+00 - val_loss: 67.2059
# Epoch 64/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9239 - loss: 1.2685 - val_accuracy: 0.0000e+00 - val_loss: 70.8511
# Epoch 65/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9419 - loss: 1.1140 - val_accuracy: 0.0000e+00 - val_loss: 73.2228
# Epoch 66/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9492 - loss: 1.0412 - val_accuracy: 0.0000e+00 - val_loss: 63.6867
# Epoch 67/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9401 - loss: 1.2702 - val_accuracy: 0.0000e+00 - val_loss: 74.8008
# Epoch 68/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9466 - loss: 1.1203 - val_accuracy: 0.0000e+00 - val_loss: 68.3349
# Epoch 69/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9366 - loss: 1.2666 - val_accuracy: 0.0000e+00 - val_loss: 67.8185
# Epoch 70/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9299 - loss: 1.2618 - val_accuracy: 0.0000e+00 - val_loss: 67.5882
# Epoch 71/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9433 - loss: 0.9800 - val_accuracy: 0.0000e+00 - val_loss: 77.7344
# Epoch 72/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9269 - loss: 1.1657 - val_accuracy: 0.0000e+00 - val_loss: 78.1384
# Epoch 73/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9391 - loss: 1.2878 - val_accuracy: 0.0000e+00 - val_loss: 81.9610
# Epoch 74/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9344 - loss: 1.6016 - val_accuracy: 0.0000e+00 - val_loss: 66.5149
# Epoch 75/75
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9513 - loss: 1.0983 - val_accuracy: 0.0000e+00 - val_loss: 66.7278

# %%
# Step 6: Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_accuracy:.2f}")

# Step 7: Generate classification report
y_pred = model.predict(X_test)
y_pred_labels = encoder.inverse_transform(y_pred)
y_test_labels = encoder.inverse_transform(y_test)
print(classification_report(y_test_labels, y_pred_labels))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9289 - loss: 3.1897
# Test accuracy: 0.86
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#            1       0.67      1.00      0.80         2
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         2
#            5       0.50      1.00      0.67         2
#            6       1.00      0.50      0.67         2
#            7       0.50      1.00      0.67         2
#            8       1.00      1.00      1.00         2
#            9       1.00      1.00      1.00         2
#           10       0.67      1.00      0.80         2
#           11       1.00      1.00      1.00         2
#           12       0.67      1.00      0.80         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
#           16       1.00      1.00      1.00         2
#           17       0.50      1.00      0.67         2
#           18       1.00      1.00      1.00         2
#           19       0.67      1.00      0.80         2
#           20       1.00      1.00      1.00         2
#           21       0.50      1.00      0.67         2
#           22       1.00      1.00      1.00         2
#           23       1.00      1.00      1.00         2
#           24       1.00      1.00      1.00         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         2
#           28       1.00      1.00      1.00         2
#           29       1.00      1.00      1.00         2
#           30       1.00      0.50      0.67         2
#           31       0.67      1.00      0.80         2
#           32       1.00      1.00      1.00         2
#           33       1.00      1.00      1.00         2
#           34       1.00      1.00      1.00         2
#           35       0.67      1.00      0.80         2
#           36       1.00      0.50      0.67         2
#           37       1.00      1.00      1.00         2
#           38       1.00      1.00      1.00         2
#           39       0.50      0.50      0.50         2
#           40       1.00      1.00      1.00         2
#           41       1.00      1.00      1.00         2
#           42       1.00      1.00      1.00         2
#           43       0.50      1.00      0.67         2
#           44       1.00      1.00      1.00         2
#           45       1.00      1.00      1.00         2
#           46       1.00      1.00      1.00         2
#           47       1.00      1.00      1.00         2
#           48       1.00      1.00      1.00         2
#           49       0.50      1.00      0.67         2
#           50       1.00      0.50      0.67         2
#           51       1.00      1.00      1.00         2
#           52       1.00      0.50      0.67         2
#           53       1.00      1.00      1.00         2
#           54       1.00      1.00      1.00         2
#           55       1.00      1.00      1.00         2
#           56       1.00      1.00      1.00         2
#           57       0.67      1.00      0.80         2
#           58       1.00      1.00      1.00         2
#           59       0.67      1.00      0.80         2
#           60       0.50      1.00      0.67         2
#           61       1.00      1.00      1.00         2
#           62       0.67      1.00      0.80         2
#           63       0.67      1.00      0.80         2
#           64       1.00      1.00      1.00         2
#           65       1.00      1.00      1.00         2
#           66       1.00      1.00      1.00         2
#           67       1.00      1.00      1.00         2
#           68       0.00      0.00      0.00         2
#           69       1.00      1.00      1.00         2
#           70       1.00      1.00      1.00         2
#           71       1.00      1.00      1.00         2
#           72       1.00      1.00      1.00         2
#           73       1.00      1.00      1.00         2
#           74       1.00      1.00      1.00         2
#           75       1.00      1.00      1.00         2
#           76       1.00      1.00      1.00         2
#           77       1.00      1.00      1.00         2
#           78       1.00      1.00      1.00         2
#           79       1.00      1.00      1.00         2
#           80       1.00      1.00      1.00         2
#           81       0.67      1.00      0.80         2
#           82       1.00      1.00      1.00         2
#           83       0.50      0.50      0.50         2
#           84       0.50      1.00      0.67         2
#           85       1.00      1.00      1.00         2
#           86       1.00      1.00      1.00         2
#           87       1.00      1.00      1.00         2
#           88       1.00      1.00      1.00         2
#           89       1.00      1.00      1.00         2
#           90       0.00      0.00      0.00         2
#           91       0.00      0.00      0.00         2
#           92       0.00      0.00      0.00         2
#           93       0.00      0.00      0.00         2
#           94       0.00      0.00      0.00         2
#           95       0.00      0.00      0.00         2
#           96       0.00      0.00      0.00         2
#           97       0.00      0.00      0.00         2
#           98       0.00      0.00      0.00         2
#           99       0.00      0.00      0.00         2
#          100       1.00      1.00      1.00         2
#
#     accuracy                           0.85       200
#    macro avg       0.80      0.85      0.81       200
# weighted avg       0.80      0.85      0.81       200
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\PC-MOH\miniconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import matplotlib.pyplot as plt

# Plot the training loss over epochs
plt.plot(history.history['loss'], label='Training Loss')  # Training loss over epochs
plt.plot(history.history['val_loss'], label='Validation Loss')  # Training loss over epochs
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Loss')  # Y-axis label
plt.title('Training Loss Over Epochs')  # Plot title
plt.legend()  # Display the legend
plt.show()  # Display the plot

# Plot the training accuracy over epochs
plt.plot(history.history['accuracy'], label='Training Accuracy')  # Training accuracy over epochs
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Training accuracy over epochs
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label
plt.title('Training Accuracy Over Epochs')  # Plot title
plt.legend()  # Display the legend
plt.show()  # Display the plot
