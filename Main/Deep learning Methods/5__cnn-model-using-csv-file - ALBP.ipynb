# %%
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from tensorflow import keras
from keras import backend as K


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
# print(check_output(["ls", "../input"]).decode("utf8"))


# Any results you write to the current directory are saved as output.

# %%
# Read training and test data files
train = pd.read_csv("data/train_test/ALBP/train_ALBP.csv").values
test  = pd.read_csv("data/train_test/ALBP/test_ALBP.csv").values

# %%
print(len(train), len(test))
# Out:
# 1200 200

# %%
# Reshape and normalize training data
trainX = train[:, :-1].reshape(train.shape[0],1,150, 100).astype( 'float32' )
X_train = trainX / 255.0

y_train = train[:, -1]


# Reshape and normalize test data
testX = test[:, :-1].reshape(test.shape[0],1, 150, 100).astype( 'float32' )
X_test = testX / 255.0

y_test = test[:, -1]

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)

# %%
# Build the model
# model = Sequential()
# # K.set_image_dim_ordering('th')
# # K.set_image_data_format('channels_first')
# model.add(Convolution2D(30, 5, 5, padding= 'valid' , input_shape=(1, 150, 100),activation= 'relu' ))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Convolution2D(15, 3, 3, activation= 'relu' ))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.2))
# model.add(Flatten())
# # model.add(Dense(128, activation= 'relu' ))
# # model.add(Dense(50, activation= 'relu' ))
# # model.add(Dense(500, activation= 'relu' ))
# model.add(Dense(128, activation= 'relu' ))
# model.add(Dense(100, activation= 'softmax' ))

# ===========================================================
# Build the model
model = Sequential()
# K.set_image_dim_ordering('th')
K.set_image_data_format('channels_first')
model.add(Convolution2D(30, 5, 5, padding= 'valid' , input_shape=(1, 150, 100),activation= 'relu' ))
model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Convolution2D(15, 3, 3, activation= 'relu' ))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.5))
model.add(Flatten())
# model.add(Dense(128, activation= 'relu' ))
# model.add(Dense(50, activation= 'relu' ))
# model.add(Dense(500, activation= 'relu' ))
# model.add(Dense(512, activation= 'relu' ))
# model.add(Dropout(0.3))
model.add(Dense(256, activation= 'relu' ))
model.add(Dense(128, activation= 'relu' ))
model.add(Dropout(0.5))
model.add(Dense(100, activation= 'softmax' ))

# Compile model
model.compile(loss= 'categorical_crossentropy' , optimizer= 'adam' , metrics=[ 'accuracy' ])

# %%
# Train the model
history = model.fit(X_train, y_train,
          validation_split=0.2,
          epochs=100,
          batch_size= 32,
          callbacks=[keras.callbacks.EarlyStopping(patience=50, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.0074 - loss: 4.6108 - val_accuracy: 0.0000e+00 - val_loss: 4.7083
# Epoch 2/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0135 - loss: 4.5671 - val_accuracy: 0.0000e+00 - val_loss: 5.4720
# Epoch 3/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0171 - loss: 4.4805 - val_accuracy: 0.0000e+00 - val_loss: 5.6886
# Epoch 4/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.0156 - loss: 4.4676 - val_accuracy: 0.0000e+00 - val_loss: 5.8178
# Epoch 5/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.0102 - loss: 4.4655 - val_accuracy: 0.0000e+00 - val_loss: 6.3805
# Epoch 6/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0128 - loss: 4.4420 - val_accuracy: 0.0000e+00 - val_loss: 6.4789
# Epoch 7/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0084 - loss: 4.4303 - val_accuracy: 0.0000e+00 - val_loss: 6.5681
# Epoch 8/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0189 - loss: 4.4328 - val_accuracy: 0.0000e+00 - val_loss: 6.7681
# Epoch 9/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.0199 - loss: 4.4068 - val_accuracy: 0.0000e+00 - val_loss: 7.4243
# Epoch 10/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.0163 - loss: 4.4204 - val_accuracy: 0.0000e+00 - val_loss: 6.7538
# Epoch 11/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.0091 - loss: 4.4155 - val_accuracy: 0.0000e+00 - val_loss: 6.7599
# Epoch 12/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.0150 - loss: 4.4125 - val_accuracy: 0.0000e+00 - val_loss: 7.1434
# Epoch 13/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0193 - loss: 4.4079 - val_accuracy: 0.0000e+00 - val_loss: 7.0155
# Epoch 14/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0024 - loss: 4.4200 - val_accuracy: 0.0000e+00 - val_loss: 7.5463
# Epoch 15/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0042 - loss: 4.4250 - val_accuracy: 0.0000e+00 - val_loss: 7.0066
# Epoch 16/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0176 - loss: 4.4000 - val_accuracy: 0.0000e+00 - val_loss: 7.2863
# Epoch 17/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0079 - loss: 4.4018 - val_accuracy: 0.0000e+00 - val_loss: 8.0525
# Epoch 18/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0111 - loss: 4.3769 - val_accuracy: 0.0000e+00 - val_loss: 8.1070
# Epoch 19/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0266 - loss: 4.3866 - val_accuracy: 0.0000e+00 - val_loss: 7.6533
# Epoch 20/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0181 - loss: 4.3849 - val_accuracy: 0.0000e+00 - val_loss: 8.0734
# Epoch 21/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0094 - loss: 4.3736 - val_accuracy: 0.0000e+00 - val_loss: 7.9069
# Epoch 22/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.0198 - loss: 4.3706 - val_accuracy: 0.0000e+00 - val_loss: 8.4434
# Epoch 23/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0115 - loss: 4.3638 - val_accuracy: 0.0000e+00 - val_loss: 8.3910
# Epoch 24/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0127 - loss: 4.3637 - val_accuracy: 0.0000e+00 - val_loss: 8.3109
# Epoch 25/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0181 - loss: 4.3303 - val_accuracy: 0.0000e+00 - val_loss: 8.8533
# Epoch 26/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0284 - loss: 4.2872 - val_accuracy: 0.0000e+00 - val_loss: 8.9303
# Epoch 27/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0445 - loss: 4.2396 - val_accuracy: 0.0000e+00 - val_loss: 10.1944
# Epoch 28/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.0545 - loss: 4.1863 - val_accuracy: 0.0000e+00 - val_loss: 9.7120
# Epoch 29/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0460 - loss: 4.1361 - val_accuracy: 0.0000e+00 - val_loss: 9.6237
# Epoch 30/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0381 - loss: 4.0773 - val_accuracy: 0.0000e+00 - val_loss: 9.9422
# Epoch 31/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0595 - loss: 4.0342 - val_accuracy: 0.0000e+00 - val_loss: 10.6670
# Epoch 32/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0532 - loss: 4.0228 - val_accuracy: 0.0000e+00 - val_loss: 11.0220
# Epoch 33/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0399 - loss: 3.9965 - val_accuracy: 0.0000e+00 - val_loss: 12.1682
# Epoch 34/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.0495 - loss: 3.9731 - val_accuracy: 0.0000e+00 - val_loss: 11.3667
# Epoch 35/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.0614 - loss: 3.8780 - val_accuracy: 0.0000e+00 - val_loss: 11.5734
# Epoch 36/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.0815 - loss: 3.8820 - val_accuracy: 0.0000e+00 - val_loss: 11.5011
# Epoch 37/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.0797 - loss: 3.8198 - val_accuracy: 0.0000e+00 - val_loss: 12.2203
# Epoch 38/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.0933 - loss: 3.7739 - val_accuracy: 0.0000e+00 - val_loss: 11.6364
# Epoch 39/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.0886 - loss: 3.7040 - val_accuracy: 0.0000e+00 - val_loss: 12.4292
# Epoch 40/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.0942 - loss: 3.7159 - val_accuracy: 0.0000e+00 - val_loss: 12.1436
# Epoch 41/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.0911 - loss: 3.6640 - val_accuracy: 0.0000e+00 - val_loss: 13.2828
# Epoch 42/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.0971 - loss: 3.6006 - val_accuracy: 0.0000e+00 - val_loss: 12.2848
# Epoch 43/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.1046 - loss: 3.6064 - val_accuracy: 0.0000e+00 - val_loss: 12.7823
# Epoch 44/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.0892 - loss: 3.6772 - val_accuracy: 0.0000e+00 - val_loss: 13.4487
# Epoch 45/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.1022 - loss: 3.6015 - val_accuracy: 0.0000e+00 - val_loss: 12.6694
# Epoch 46/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.0993 - loss: 3.5856 - val_accuracy: 0.0000e+00 - val_loss: 13.4012
# Epoch 47/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.1178 - loss: 3.5052 - val_accuracy: 0.0000e+00 - val_loss: 13.4558
# Epoch 48/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.1194 - loss: 3.4753 - val_accuracy: 0.0000e+00 - val_loss: 14.0477
# Epoch 49/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.1101 - loss: 3.5055 - val_accuracy: 0.0000e+00 - val_loss: 13.0421
# Epoch 50/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.1201 - loss: 3.4012 - val_accuracy: 0.0000e+00 - val_loss: 12.9846
# Epoch 51/100
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.1212 - loss: 3.5108 - val_accuracy: 0.0000e+00 - val_loss: 13.3618

# %%
# Test the model
score = model.evaluate(X_test, y_test, batch_size=32)
print('accuracy:', score)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.0090 - loss: 4.5925
# accuracy: [4.607822895050049, 0.014999999664723873]

# %%
model.save("cnn_model_ALBP.keras")
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 30, 30, 20)     │           780 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 15, 10)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4500)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │     2,304,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 100)            │        12,900 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,447,250 (28.41 MB)
#  Trainable params: 2,482,416 (9.47 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 4,964,834 (18.94 MB)

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt

# Plot the training loss over epochs
plt.plot(history.history['loss'], label='Training Loss')  # Training loss over epochs
plt.plot(history.history['val_loss'], label='Validation Loss')  # Validation loss over epochs
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Loss')  # Y-axis label
plt.title('Training Loss Over Epochs')  # Plot title
plt.legend()  # Display the legend
plt.show()  # Display the plot

# Plot the training accuracy over epochs
plt.plot(history.history['accuracy'], label='Training Accuracy')  # Training accuracy over epochs
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')  # Validation accuracy over epochs
plt.xlabel('Epochs')  # X-axis label
plt.ylabel('Accuracy')  # Y-axis label
plt.title('Training Accuracy Over Epochs')  # Plot title
plt.legend()  # Display the legend
plt.show()  # Display the plot
